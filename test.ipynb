# %%
from sklearn.linear_model import LogisticRegression
import seaborn as sn
 
X = [[1000],[2000],[15000],[30000]]
Y = [0,1,0,1]
 
model = LogisticRegression()
model.fit(X,Y)
 
print(model.predict([[10000]]))
